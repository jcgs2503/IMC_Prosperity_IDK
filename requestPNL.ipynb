# %%
# https://bz97lt8b1e.execute-api.eu-west-1.amazonaws.com/prod/results/tutorial/cf22c46b-1dc5-4dc9-b34b-6988f21aae31
import requests
# Pearl Only
id_p1 = "3d8fda5d-37d8-4589-86a1-4daaf834833c"
# Pearl and Bananas
id_pb1 = "f996d510-7f0e-4a1a-bba4-d6b9b5fa0bc1" # mid price method
id_pb2 = "e02bb3b5-41f5-44a2-9f7d-83094ddc3fd5"  # average bid/ask method
id_pb3 = "53c71ed0-cd24-4218-ac72-8ed0f9912515"  # bid_ask_qnt_independent

url = 'https://bz97lt8b1e.execute-api.eu-west-1.amazonaws.com/prod/results/tutorial/' + id_pb3
token = "eyJraWQiOiJ4M3NhZjFZTkNsRGwyVDljemdCR01ybnVVMlJlNDNjb1E1UGxYMWgwb2tBPSIsImFsZyI6IlJTMjU2In0.....P03ztMtlPlb1UpdtlwYdZ7t-wcIPl-wd7mvngcwBs0OOSDD2ZV60ouu6v_kRYwmm86TXSRJnOeI3MTXuQtPwr7c7VtZfHGcGWmiCQs9JGR3gKsTzgoSsf0TtlCf2Drt-FoGQ1SSHYZWFQRJ0IGiMXPCArJXeOi-ARmxGYTxwJbmwi0KyJZfdkctQTTRUgQWF1RR4xOixNM-VnGF2KfMX2n0sRPsRvwcs2qj0F6BEOTvYVI3C2NthE62OPkBzbq1uYtESvTzc5GTKa0gxmYH9UxzKfsHc8LDHffWbre_bdbfILe4SjAjE1fj1fJM2UiZNUN2zIBYHX-p7fMrb8_duuA"
headers = {'Authorization': 'Bearer ' + token}
r = requests.get(url, headers=headers)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# spread = 2
plt.rcParams['savefig.facecolor'] = 'white'
data = r.json()
pnl = data['algo']['profitAndLoss']
x = [int(i['timestamp'])for i in pnl]
y = [float(i['value']) for i in pnl]
# plt.figure(figsize=(18, 9))
plt.plot(x,y)
plt.title(f"Pearl & Bananas, Profit = {data['algo']['summary']['profit']}")
plt.xlabel('Time')
plt.ylabel('PnL')
# plt.show()
plt.savefig(f"plots/round1/basic_model_pearls&bananas_ba_qnt_independent.png", dpi=300, bbox_inches='tight')
data['algo']['summary']
# Out:
# {'round': 'ROUND1_ALGO',
#  'handler': None,
#  'status': 'FINISHED',
#  'score': None,
#  'profit': 1904.92,
# ...

# %%
bananas_trade = []
for i in data['algo']['tradeHistory']:
    if i['symbol'] == 'BANANAS':
        bananas_trade.append(i['price'])
plt.plot(bananas_trade)

# %%
import numpy as np
trades = {121:1, 122:3, 123:7}
sum([trades[key]*key for key in trades.keys()])/sum(trades.values())
# Out:
# 122.54545454545455

# %%
sum(trades.values())
# Out:
# 11
