# %%
# https://bz97lt8b1e.execute-api.eu-west-1.amazonaws.com/prod/results/tutorial/cf22c46b-1dc5-4dc9-b34b-6988f21aae31
import requests
id1 = "f549c4e7-85b1-41b5-aba3-5461888deb19" #spread 1
id2 = "cf22c46b-1dc5-4dc9-b34b-6988f21aae31" #spread 2
id3 = "028eab9f-0821-4a60-9d76-7ceb9665f47b" #spread 3
url = 'https://bz97lt8b1e.execute-api.eu-west-1.amazonaws.com/prod/results/tutorial/' + id2
headers = {'Authorization': 'Bearer eyJraWQiOiJ4M3NhZjFZTkNsRGwyVDljemdCR01ybnVVMlJlNDNjb1E1UGxYMWgwb2tBPSIsImFsZyI6IlJTMjU2In0.....EmGKTtlJWfUrfmrT5Px-iv1CWe5FnCr3XWl_u7hsKu8ofvbg8wjFgv5DBX5rrXgfGsLOt6ctMOiqjEGV1VRJ8VcVGFjxLBr3spCe8VtG7VX0NcexO25ytccHfSOAgbqPIl43hsRV5bj15EgEri7iK26RitooW2RsXnCNevf4rjs2Rp8sTGlmwEwGLWOeS615i_TnoA0fcvRwmHCy7GSOvgVLymTiLQCDKb5SyRGx8lYjuZMQvPKn0w7ctjaXIfNRD636DDR_oqyDc1hNzO6-ABM3nJb5hhbGuBLb_Ct7X3VLLMub7sMuULJ-w9dwPCg2k80faPX9zwXdoKAnukBpDg'}
r = requests.get(url, headers=headers)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
spread = 2
plt.rcParams['savefig.facecolor'] = 'white'
data = r.json()
pnl = data['algo']['profitAndLoss']
x = [int(i['timestamp'])for i in pnl]
y = [float(i['value']) for i in pnl]
# plt.figure(figsize=(18, 9))
plt.plot(x,y)
plt.title(f"Pearl Only, Default Spread = {spread}")
plt.xlabel('Time')
plt.ylabel('PnL')
# plt.show()
plt.savefig(f"plots/round1/basic_model_pearl_only_spread_{spread}.png", dpi=300, bbox_inches='tight')
