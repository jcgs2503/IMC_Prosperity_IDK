# %%
# https://bz97lt8b1e.execute-api.eu-west-1.amazonaws.com/prod/results/tutorial/cf22c46b-1dc5-4dc9-b34b-6988f21aae31
import requests
# Pearl Only
id_p1 = "3d8fda5d-37d8-4589-86a1-4daaf834833c"
# Pearl and Bananas
id_pb1 = "f996d510-7f0e-4a1a-bba4-d6b9b5fa0bc1" # mid price method
id_pb2 = "e02bb3b5-41f5-44a2-9f7d-83094ddc3fd5"  # average bid/ask method
id_pb3 = "53c71ed0-cd24-4218-ac72-8ed0f9912515"  # bid_ask_qnt_independent
id_pb4 = "12a4bf2a-e1a0-4d05-b383-478187ed2d20" # , spread = 3
id_pb5 = "733378af-0174-4832-b213-86b37dddf3d7" 
id_last = "fb9d66fd-b720-4b2b-92f2-8420c153e321"  # Current Best

url = 'https://bz97lt8b1e.execute-api.eu-west-1.amazonaws.com/prod/results/tutorial/' + id_last
token = "eyJraWQiOiJ4M3NhZjFZTkNsRGwyVDljemdCR01ybnVVMlJlNDNjb1E1UGxYMWgwb2tBPSIsImFsZyI6IlJTMjU2In0.....a4gKU6Z7QaCg6YlKDzrxGJHees8eguQnSWb5nn_j7pvwLWI2aHXdMRWkvwEYRbn-iawLZ-48AmmyRh3vOTU0XVSWP8H9jRzq2PFR6im97Wu5_CX0HnOhkKvYg04Xm3B6_ze-ztK-wo5Tj5m_0zbr4GtF7-Vm5DKi8EcHubh_PpJvNdT32RNZR4Dp3ATB3bqNXLKndQaGEevJ7vCcaedbsfEsSvopEQKLvG0dPj0U7vkTSyHKpevENbzxwLGnzCk3tMb87Bq1Nwu8HgBE0KuU2HHfONmYdP0pdxIJCie1XUBWaPp-FMf9GTdqrHjbOg0alAme-hV7kJ2rxPHG14pi7g"
headers = {'Authorization': 'Bearer ' + token}
r = requests.get(url, headers=headers)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# spread = 2
plt.rcParams['savefig.facecolor'] = 'white'
data = r.json()
pnl = data['algo']['profitAndLoss']
x = [int(i['timestamp'])for i in pnl]
y = [float(i['value']) for i in pnl]
# plt.figure(figsize=(18, 9))
plt.plot(x,y)
plt.title(f"Pearl & Bananas, Profit = {data['algo']['summary']['profit']}")
plt.xlabel('Time')
plt.ylabel('PnL')
# plt.show()
plt.savefig(f"plots/round1/basic_model_pearls&bananas_current_best.png", dpi=300, bbox_inches='tight')
data['algo']['summary']
# Out:
# {'round': 'ROUND1_ALGO',
#  'handler': None,
#  'status': 'FINISHED',
#  'score': None,
#  'profit': 2995.92,
# ...

# %%
2*np.log(5)
# Out:
# 3.2188758248682006
